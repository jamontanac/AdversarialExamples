# %% [markdown]
# # Reporte General

# %%
# for each model we iterate and save for each defense the accuracy for original aggregating the attack
models = ["Regnet_y","Regnet_x","Resnet"]
attacks = ["CarliniL2","PGD","DeepFool","FSGM"]
result={}

for attack in attacks:
    for model in models:
        report = catalog.load(f'{model}_model_Report_{attack}@Dataset')
        for defense in report.keys():
            elements=report[defense]['Accuracies']

            if model not in result:
                result[model]=[{defense:report[defense]['Accuracies']}]
            else:
                result[model].append({defense:report[defense]['Accuracies']})
# Out:
# [04/04/24 19:52:38] INFO     Loading data from Regnet_y_model_Report_CarliniL2@Dataset          ]8;id=889322;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=383013;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Regnet_x_model_Report_CarliniL2@Dataset          ]8;id=498119;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=371065;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Resnet_model_Report_CarliniL2@Dataset            ]8;id=755414;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=205475;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Regnet_y_model_Report_PGD@Dataset                ]8;id=574385;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=325204;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Regnet_x_model_Report_PGD@Dataset                ]8;id=957612;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=59143;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Resnet_model_Report_PGD@Dataset (JSONDataset)... ]8;id=560160;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=765998;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                     INFO     Loading data from Regnet_y_model_Report_DeepFool@Dataset           ]8;id=983274;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=241305;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Regnet_x_model_Report_DeepFool@Dataset           ]8;id=622257;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=449696;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Resnet_model_Report_DeepFool@Dataset             ]8;id=742580;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=869724;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Regnet_y_model_Report_FSGM@Dataset               ]8;id=143657;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=17291;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Regnet_x_model_Report_FSGM@Dataset               ]8;id=708238;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=27277;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Resnet_model_Report_FSGM@Dataset                 ]8;id=79551;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=663944;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
models = ["Regnet_y", "Regnet_x", "Resnet"]
attacks = ["CarliniL2", "PGD", "DeepFool", "FSGM"]
results = []  # List to hold all results for easy plotting

for attack in attacks:
    for model in models:
        report = catalog.load(f'{model}_model_Report_{attack}@Dataset')
        for defense, data in report.items():
            accuracies = data['Accuracies']
            # Append a dictionary for each type of accuracy
            results.append({'Model': model, 'Defense': defense, 'Type': 'Original', 'Accuracy': accuracies['Original']})
            results.append({'Model': model, 'Defense': defense, 'Type': 'Adversarial', 'Accuracy': accuracies['Adversarial']})
            results.append({'Model': model, 'Defense': defense, 'Type': 'Defense', 'Accuracy': accuracies['Defense']})
# Out:
# [04/04/24 19:52:56] INFO     Loading data from Regnet_y_model_Report_CarliniL2@Dataset          ]8;id=61395;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=608639;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Regnet_x_model_Report_CarliniL2@Dataset          ]8;id=348975;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=209648;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Resnet_model_Report_CarliniL2@Dataset            ]8;id=701974;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=479977;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Regnet_y_model_Report_PGD@Dataset                ]8;id=870389;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=423910;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Regnet_x_model_Report_PGD@Dataset                ]8;id=896864;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=281305;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Resnet_model_Report_PGD@Dataset (JSONDataset)... ]8;id=676843;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=661967;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                     INFO     Loading data from Regnet_y_model_Report_DeepFool@Dataset           ]8;id=528709;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=302661;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Regnet_x_model_Report_DeepFool@Dataset           ]8;id=424745;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=23437;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Resnet_model_Report_DeepFool@Dataset             ]8;id=287053;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=521485;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Regnet_y_model_Report_FSGM@Dataset               ]8;id=307116;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=723655;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Regnet_x_model_Report_FSGM@Dataset               ]8;id=249651;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=552126;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...
#                     INFO     Loading data from Resnet_model_Report_FSGM@Dataset                 ]8;id=866361;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=165579;file:///home/jamontanac/miniconda3/envs/AdvExamples/lib/python3.10/site-packages/kedro/io/data_catalog.py#482\482]8;;\
#                              (JSONDataset)...

# %%
# Convert results to a DataFrame for easy plotting
df = pd.DataFrame(results)
df = df.query("Type != 'Original'")
df = df[df['Defense'].str.contains("JPEG")]
# Initialize a matplotlib figure
plt.figure(figsize=(9, 6))

# Use seaborn to create the box plot
sns.violinplot(x='Model', y='Accuracy', hue='Type', data=df,split=True,inner='quart', gap= 49, )

# Add some plot aesthetics
plt.title('Accuracy Distribution by Model for JPEG defenses')
plt.ylabel('Accuracy (%)')
plt.xlabel('Model')
plt.legend(title='Type')

# Display the plot
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 900x600 with 1 Axes>

# %%
# Convert results to a DataFrame for easy plotting
df = pd.DataFrame(results)
df = df.query("Type != 'Original' or Type != 'Defense'")
# df = df[df['Defense'].str.contains("JPEG")]
# Initialize a matplotlib figure
plt.figure(figsize=(10, 6))

# Use seaborn to create the box plot
sns.violinplot(x='Model', y='Accuracy', data=df, )

# Add some plot aesthetics
plt.title('Accuracy Distribution by Model for JPEG defenses')
plt.ylabel('Accuracy (%)')
plt.xlabel('Model')

# Display the plot
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 1000x600 with 1 Axes>

# %%
import math
# Convert results to a DataFrame for easy plotting
df = pd.DataFrame(results)
df = df.query("Type != 'Original'")
df = df[df['Defense'].str.contains("JPEG")]
unique_defenses = df.Defense.unique()
# Assuming unique_defenses is already defined
num_defenses = len(unique_defenses)
num_columns = 3
num_rows = math.ceil(num_defenses / num_columns)

# Initialize the figure with a specific size
fig, axes = plt.subplots(num_rows, num_columns, figsize=(20, num_rows * 6), constrained_layout=True)

# Flatten the axes array for easy iteration if there's more than one row
if num_rows > 1:
    axes = axes.flatten()
else:
    axes = [axes]

# Loop over each unique defense and create its plot
for i, defense in enumerate(unique_defenses):
    ax = axes[i]
    df_defense = df[df['Defense'] == defense]

    # Use seaborn to create the box plot for the current defense on the specified axes
    sns.boxplot(x='Model', y='Accuracy', hue='Type', data=df_defense, ax=ax)

    # Set titles and labels
    ax.set_title(f'Defense: {defense}')
    ax.set_ylabel('Accuracy (%)')
    ax.set_xlabel('Model')


# Hide any unused axes if the number of plots is not a perfect multiple of the layout
for i in range(len(unique_defenses), num_columns * num_rows):
    fig.delaxes(axes[i])

# Automatically adjust subplot params so that the subplot(s) fits in to the figure area
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <Figure size 2000x2400 with 11 Axes>
